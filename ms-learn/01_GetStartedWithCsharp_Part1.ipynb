# %% [markdown]
# # Microsoft Learn - Get started with C#, Part 1

# %% [markdown]
# https://learn.microsoft.com/en-us/training/paths/get-started-c-sharp-part-1/

# %% [markdown]
# ## Write your first C# code

# %% [markdown]
# https://learn.microsoft.com/en-us/training/modules/csharp-write-first/

# %% [markdown]
# ### Exercise - Write your first code

# %% [markdown]
# Create your first line of code, the all glorious Hello World! sentence.

# %%
Console.WriteLine("Hello World!");
# Out:
# Hello World!

# %% [markdown]
# Comment out the code. (or create a comment)

# %%
// This is a comment and does nothing

# %% [markdown]
# Now let's write some more lines

# %%
Console.Write("Congratulations!");
Console.Write(" ");
Console.Write("You wrote your first lines of code.")
# Out:
# Congratulations! You wrote your first lines of code.

# %%
Console.WriteLine("Congratulations!");
Console.Write("You wrote your first lines of code.");
# Out:
# Congratulations!
# You wrote your first lines of code.

# %% [markdown]
# ### Learn how it works

# %%
Console.WriteLine("This is a string");
# Out:
# This is a string

# %% [markdown]
# **Compiler:**\
# A special program that converts your source code into a different format that the computer's CPU can execute.
#
# **Syntax:**\
# The specific rules for writing code.
#
# **Literal string:**\
# A phrase surrounded by double-quotation marks. `"..."`
#
# **Class:**\
# Classes "own" methodes. The `Console` part of the `Console.WriteLine("This is a string");` code is a class.
#
# **Member acces operator:**\
# The dot that seperates the classname and the methode name. `.`
#
# **Method:**\
# Each methode has one job within a class. You can always spot a method because it has a set of parentheses after it. Some methods need input parameters, while others don't. `WriteLine` is a methode of the class `Console`.
#
# **Method invocation operator:**\
# The parentheses after the methode. `(...)`
#
# **End of statement operator:**\
# A **statement** is a complete instuction. The semicolon tells the compiler that you've finished entering the command. `;`

# %% [markdown]
# ### Complete the challenge

# %%
Console.WriteLine("This is the first line.");
Console.Write("This is the second line.");
# Out:
# This is the first line.
# This is the second line.

# %% [markdown]
# ## Store and retrieve data

# %% [markdown]
# https://learn.microsoft.com/en-us/training/modules/csharp-literals-variables/

# %% [markdown]
# ### Exercise - Print literal values

# %% [markdown]
# #### Character literals

# %%
Console.WriteLine('b');
# Out:
# b

# %%
//Console.WriteLine('Hello World!');
# Out:
# (1,19): error CS1012: Too many characters in character literal

# %% [markdown]
# #### Integer literals

# %%
Console.WriteLine(123);
# Out:
# 123

# %% [markdown]
# #### Floating-point literals

# %% [markdown]
# | Float Type |   Precision      |
# | ---------- | ---------------  |
# | float      |   ~6-9 digits    |
# | double     |   ~15-17 digits  |
# | decimal    |    28-29 digits  |

# %% [markdown]
# **Float**

# %%
Console.WriteLine(0.25F);
Console.WriteLine(1.23f);
# Out:
# 0.25
# 1.23

# %% [markdown]
# **Double**

# %%
Console.WriteLine(2.625);
# Out:
# 2.625

# %% [markdown]
# **Decimal**

# %%
Console.WriteLine(12.39816m);
# Out:
# 12.39816

# %% [markdown]
# #### Boolean literals

# %%
Console.WriteLine(true);
Console.WriteLine(false);
# Out:
# True
# False

# %% [markdown]
# ### Declare variables

# %% [markdown]
# **Literal:**\
# A hard-coded value. Hard-coded values are values that are constant and unchanged throughout the execution of the program.
#
# **Variable:**\
# A variable is a container for storing a type of value. Variables can be assigned, read, and changed.

# %% [markdown]
# Declare a `string` type variable called `firstName`.

# %%
string firstName;

# %% [markdown]
# #### Variable name rules and conventions

# %% [markdown]
# Not only does the name of a variable have to follow certain syntax rules, it should also be used to make the code more human-readable and understandable. That's a lot to ask of one line of code!
#
# Here's a few important considerations about variable names:
# - Variable names can contain alphanumeric characters and the underscore character. Special characters like the hash symbol `#` (also known as the number symbol or pound symbol) or dollar symbol `$` are not allowed.
# - Variable names must begin with an alphabetical letter or an underscore, not a number.
# - Variable names are case-sensitive, meaning that `string Value;` and `string value;` are two different variables.
# - Variable names must not be a C# keyword. For example, you cannot use the following variable declarations: `decimal decimal;` or `string string;`.
#
# There are coding conventions that help keep variables readable and easy to identify. As you develop larger applications, these coding conventions can help you keep track of variables among other text.
#
# Here are some coding conventions for variables:
# - Variable names should use **camel case**, which is a style of writing that uses a lower-case letter at the beginning of the first word and an upper-case letter at the beginning of each subsequent word. For example, `string thisIsCamelCase;`.
# - Variable names should begin with an **alphabetical letter**. Developers use the underscore for a special purpose, so try to not use that for now.
# - Variable names should be descriptive and meaningful in your app. Choose a name for your variable that represents the kind of data it will hold.
# - Variable names should be one or more entire words appended together. Don't use contractions or abbreviations because the name of the variable (and therefore, its purpose) may be unclear to others who are reading your code.
# - Variable names shouldn't include the data type of the variable. You might see some advice to use a style like `string strValue;`. That advice is no longer current.

# %%
char userOption;

int gameScore;

decimal particlesPerMillion;

bool processedCustomer;

# %% [markdown]
# ### Exercise - Setting and getting values from variables

# %%
string firstName;
firstName = "Bob";
Console.WriteLine(firstName);
firstName = "Liem";
Console.WriteLine(firstName);
firstName = "Isabella";
Console.WriteLine(firstName);
firstName = "Yasmin";
Console.WriteLine(firstName);
# Out:
# Bob
# Liem
# Isabella
# Yasmin

# %%
string firstName = "Bob";
Console.WriteLine(firstName);
# Out:
# Bob

# %% [markdown]
# ### Declare implicitly typed local variables

# %%
var message = "Hello World!";

# %% [markdown]
# ### Complete the challenge

# %%
string firstName = "Bob";
int messageAmount = 3;
float temperature = 34.4f;

Console.Write("Hello, ");
Console.Write(firstName);
Console.Write("! You have ");
Console.Write(messageAmount);
Console.Write(" messages in your inbox. The temperature is ");
Console.Write(temperature);
Console.Write(" celsius.");
# Out:
# Hello, Bob! You have 3 messages in your inbox. The temperature is 34.4 celsius.

# %% [markdown]
# ## Perform basic string formatting

# %% [markdown]
# https://learn.microsoft.com/en-us/training/modules/csharp-basic-formatting/

# %% [markdown]
# ### Exercise - Combine strings using character escape sequences

# %% [markdown]
# `\` is used as an escape character in a string.
#
# - Using `\n` will create a newline.
# - Using `\t` will create a tab.
# - Using `\` in front of a `"` will not end the string, but show the `"`.
# - Using `\\` will show the `\`.
# - Use `\u` followed by the correct hex-number to get Unicode (UTF-16) characters.

# %%
Console.WriteLine("Hello\nWorld!");
Console.WriteLine("Hello\tWorld!");
Console.WriteLine("Hello \"World\"!");
Console.WriteLine("c:\\source\\repos");
// Kon'nichiwa World
Console.WriteLine("\u3053\u3093\u306B\u3061\u306F World!");
# Out:
# Hello
# World!
# Hello	World!
# Hello "World"!
# c:\source\repos
# こんにちは World!

# %%
Console.WriteLine("Generating invoices for customer \"Contoso Corp\" ... \n");
Console.WriteLine("Invoice: 1021\t\tComplete!");
Console.WriteLine("Invoice: 1022\t\tComplete!");
Console.Write("\nOutput Directory:\t");
# Out:
# Generating invoices for customer "Contoso Corp" ...
#
# Invoice: 1021		Complete!
# Invoice: 1022		Complete!
#
# Output Directory:

# %% [markdown]
# #### Verbatim string literal

# %%
Console.WriteLine(@"    c:\source\repos
        (this is where your code goes)");
# Out:
#     c:\source\repos
#         (this is where your code goes)

# %%
Console.WriteLine("Generating invoices for customer \"Contoso Corp\" ... \n");
Console.WriteLine("Invoice: 1021\t\tComplete!");
Console.WriteLine("Invoice: 1022\t\tComplete!");
Console.Write("\nOutput Directory:\t");
Console.Write(@"c:\invoices");
# Out:
# Generating invoices for customer "Contoso Corp" ...
#
# Invoice: 1021		Complete!
# Invoice: 1022		Complete!
#
# Output Directory:	c:\invoices

# %% [markdown]
# #### Unicode escape characters

# %%
Console.WriteLine("Generating invoices for customer \"Contoso Corp\" ... \n");
Console.WriteLine("Invoice: 1021\t\tComplete!");
Console.WriteLine("Invoice: 1022\t\tComplete!");
Console.Write("\nOutput Directory:\t");
Console.Write(@"c:\invoices");

// To generate Japanese invoices:
// Nihon no seikyū-sho o seisei suru ni wa:
Console.Write("\n\n\u65e5\u672c\u306e\u8acb\u6c42\u66f8\u3092\u751f\u6210\u3059\u308b\u306b\u306f\uff1a\n\t");
// User command to run an application
Console.WriteLine(@"c:\invoices\app.exe -j");
# Out:
# Generating invoices for customer "Contoso Corp" ...
#
# Invoice: 1021		Complete!
# Invoice: 1022		Complete!
#
# Output Directory:	c:\invoices
#
# 日本の請求書を生成するには：
# 	c:\invoices\app.exe -j

# %% [markdown]
# ### Exercise - Combine strings using string concatenation

# %%
string firstName = "Bob";
string greeting = "Hello";
string message = greeting + " " + firstName + "!";
Console.WriteLine(message);
# Out:
# Hello Bob!

# %% [markdown]
# If possible, avoid the use of a intermediate variable like `message` above.

# %%
string firstName = "Bob";
string greeting = "Hello";
Console.WriteLine(greeting + " " + firstName + "!");
# Out:
# Hello Bob!

# %% [markdown]
# ### Exercise - Combine strings using string inerpolation

# %%
string firstName = "Bob";
string greeting = "Hello";
string message;

message = greeting + " " + firstName + "!";     // String concatenation
message = $"{greeting} {firstName}!";           // String interpolation

# %%
string firstName = "Bob";
string message = $"Hello {firstName}!";
Console.WriteLine(message);
# Out:
# Hello Bob!

# %%
int version = 11;
string updateText = "Update to Windows";
Console.WriteLine($"{updateText} {version}!");
# Out:
# Update to Windows 11!

# %%
string projectName = "First-Project";
Console.WriteLine($@"C:\Output\{projectName}\Data");
# Out:
# C:\Output\First-Project\Data
